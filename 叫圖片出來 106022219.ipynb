# %%
import matplotlib.image as mpimg
im = mpimg.imread('九喇嘛1.JPEG')

# %%
import matplotlib.pyplot as plt
plt.imshow(im)

# %%
print(im.shape)
# Out:
# (495, 700, 3)

# %%
r_im = im[:,:,0]
plt.imshow(r_im)

# %%
b_im = im[:,:,1]
plt.imshow(b_im,cmap="Greys")

# %%
plt.hist(b_im.ravel())
# Out:
# (array([ 7147., 16661., 95022., 24318.,  7686.,  7003., 50575., 45113.,
#         16161., 76814.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
g_im = im[:,:,2]
plt.hist(g_im.ravel())
# Out:
# (array([ 11427.,  22985., 122426.,  19627.,  70431.,  13260.,   6411.,
#           7284.,  27436.,  45213.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
gb_im = g_im + b_im
plt.hist(gb_im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-dbe3fcdff6e6> in <module>()
# ----> 1 gb_im = g_im + b_im
#       2 plt.hist(gb_im)
#
# NameError: name 'b_im' is not defined

# %%
import numpy as np
print(np.mean(b_im))
print(np.median(b_im))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5eca60864a2d> in <module>()
#       1 import numpy as np
# ----> 2 print(np.mean(b_im))
#       3 print(np.median(b_im))
#
# NameError: name 'b_im' is not defined
